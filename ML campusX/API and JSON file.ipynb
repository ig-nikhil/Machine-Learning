# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.restful-api.dev/objects')

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#     id                               name  \
# 0    1                 Google Pixel 6 Pro
# 1    2  Apple iPhone 12 Mini, 256GB, Blue
# 2    3            Apple iPhone 12 Pro Max
# 3    4              Apple iPhone 11, 64GB
# 4    5             Samsung Galaxy Z Fold2
# 5    6                      Apple AirPods
# 6    7               Apple MacBook Pro 16
# 7    8               Apple Watch Series 8
# 8    9             Beats Studio3 Wireless
# 9   10            Apple iPad Mini 5th Gen
# 10  11            Apple iPad Mini 5th Gen
# 11  12                     Apple iPad Air
# 12  13                     Apple iPad Air
#
#                                                  data
# 0     {'color': 'Cloudy White', 'capacity': '128 GB'}
# 1                                                None
# 2       {'color': 'Cloudy White', 'capacity GB': 512}
# 3                {'price': 389.99, 'color': 'Purple'}
# 4                 {'price': 689.99, 'color': 'Brown'}
# ...
